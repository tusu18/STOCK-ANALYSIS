# %%
#The solution code should start right after the query statement, for example -
import numpy as np 
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
#And solve the query

# %% [markdown]
# ## Analysing the data could include finding out the trend of a stock price, e.g. how the stock price changes with respect to the Nifty 50 basket of stocks.

# %% [markdown]
# ## *INFOSYS*

# %%
df=pd.read_csv("INFY.csv")

# %%
df.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ 2017-05-15      964.25       963.5      963.50     949.10
# 1   INFY     EQ 2017-05-16      951.55       953.1      960.15     946.95
# 2   INFY     EQ 2017-05-17      955.00       951.6      958.45     943.85
# 3   INFY     EQ 2017-05-18      952.80       943.0      973.90     942.85
# 4   INFY     EQ 2017-05-19      961.75       961.5      962.70     947.85
#
#    Last Price  Close Price  Average Price  ...      Turnover  No. of Trades  \
# 0      953.25       951.55         951.49  ...  3.471580e+09          75335
# 1      956.00       955.00         952.92  ...  2.920775e+09          71808
# 2      952.90       952.80         949.48  ...  1.384110e+09          75429
# 3      960.25       961.75         962.61  ...  3.878282e+09         120990
# 4      957.40       957.95         954.18  ...  2.031155e+09          88897
#
# ...

# %%
df.describe()
# Out:
#         Prev Close   Open Price   High Price    Low Price   Last Price  \
# count   496.000000   496.000000   496.000000   496.000000   496.000000
# mean    961.505746   960.166331   970.148589   950.189415   959.942843
# std     220.856495   220.105831   223.013281   218.694264   220.978683
# min     619.100000   621.000000   628.000000   599.850000   619.500000
# 25%     734.950000   736.050000   742.475000   729.037500   734.375000
# 50%     956.750000   955.825000   963.925000   947.675000   955.675000
# 75%    1150.212500  1145.137500  1161.425000  1135.887500  1147.850000
# max    1441.100000  1449.000000  1467.900000  1430.000000  1440.000000
#
#        Close Price  Average Price  Total Traded Quantity      Turnover  \
# count    496.00000     496.000000           4.960000e+02  4.960000e+02
# mean     960.04254     960.262399           6.037975e+06  5.452230e+09
# std      221.03952     221.113239           5.448129e+06  4.768762e+09
# ...

# %%
t=df["Total Traded Quantity"]

# %%
p=df["Total Traded Quantity"]

# %%
s=df["No. of Trades"]

# %%
df.corr
# Out:
# <bound method DataFrame.corr of     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     INFY     EQ 2017-05-15      964.25      963.50      963.50     949.10
# 1     INFY     EQ 2017-05-16      951.55      953.10      960.15     946.95
# 2     INFY     EQ 2017-05-17      955.00      951.60      958.45     943.85
# 3     INFY     EQ 2017-05-18      952.80      943.00      973.90     942.85
# 4     INFY     EQ 2017-05-19      961.75      961.50      962.70     947.85
# ..     ...    ...        ...         ...         ...         ...        ...
# 491   INFY     EQ 2019-05-07      718.40      720.40      727.90     718.70
# 492   INFY     EQ 2019-05-08      724.55      721.00      726.00     716.50
# 493   INFY     EQ 2019-05-09      719.35      719.15      730.30     715.80
# 494   INFY     EQ 2019-05-10      721.05      720.80      726.00     715.00
# 495   INFY     EQ 2019-05-13      716.85      716.55      726.45     712.10
#
# ...

# %%
df["Date"]
# Out:
# 0     2017-05-15
# 1     2017-05-16
# 2     2017-05-17
# 3     2017-05-18
# 4     2017-05-19
#          ...
# 491   2019-05-07
# 492   2019-05-08
# 493   2019-05-09
# 494   2019-05-10
# 495   2019-05-13
# Name: Date, Length: 496, dtype: datetime64[ns]

# %%
df["Date"]=df["Date"].astype("datetime64")

# %%
df["Date"].min()-df["Date"].max()
# Out:
# Timedelta('-728 days +00:00:00')

# %%
vwap=(p*s)/(t)

# %%
vwap #VWAP value
# Out:
# 0       75335.0
# 1       71808.0
# 2       75429.0
# 3      120990.0
# 4       88897.0
#          ...
# 491    104342.0
# 492    162077.0
# 493    242225.0
# 494    181229.0
# 495    201194.0
# Length: 496, dtype: float64

# %%
df['Month']=df['Date'].dt.month #Splitting month year

# %%
df['Year']=df['Date'].dt.year

# %%
df['Days']=df['Date'].dt.day

# %%
df.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ 2017-05-15      964.25       963.5      963.50     949.10
# 1   INFY     EQ 2017-05-16      951.55       953.1      960.15     946.95
# 2   INFY     EQ 2017-05-17      955.00       951.6      958.45     943.85
# 3   INFY     EQ 2017-05-18      952.80       943.0      973.90     942.85
# 4   INFY     EQ 2017-05-19      961.75       961.5      962.70     947.85
#
#    Last Price  Close Price  Average Price  ...      Turnover  No. of Trades  \
# 0      953.25       951.55         951.49  ...  3.471580e+09          75335
# 1      956.00       955.00         952.92  ...  2.920775e+09          71808
# 2      952.90       952.80         949.48  ...  1.384110e+09          75429
# 3      960.25       961.75         962.61  ...  3.878282e+09         120990
# 4      957.40       957.95         954.18  ...  2.031155e+09          88897
#
# ...

# %%
df["vwap"]=vwap

# %%
df.head(20)
# Out:
#    Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0    INFY     EQ 2017-05-15      964.25      963.50      963.50     949.10
# 1    INFY     EQ 2017-05-16      951.55      953.10      960.15     946.95
# 2    INFY     EQ 2017-05-17      955.00      951.60      958.45     943.85
# 3    INFY     EQ 2017-05-18      952.80      943.00      973.90     942.85
# 4    INFY     EQ 2017-05-19      961.75      961.50      962.70     947.85
# 5    INFY     EQ 2017-05-22      957.95      958.40      966.90     956.55
# 6    INFY     EQ 2017-05-23      961.45      964.65      967.00     954.10
# 7    INFY     EQ 2017-05-24      957.30      960.00      965.50     949.60
# 8    INFY     EQ 2017-05-25      954.80      961.00      986.60     961.00
# 9    INFY     EQ 2017-05-26      983.30      987.00     1000.00     980.60
# 10   INFY     EQ 2017-05-29      995.70      990.90      996.70     975.70
# ...

# %%
df1=df.groupby(["Month","Year","Days"])

# %%
df1.head()
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     INFY     EQ 2017-05-15      964.25      963.50      963.50     949.10
# 1     INFY     EQ 2017-05-16      951.55      953.10      960.15     946.95
# 2     INFY     EQ 2017-05-17      955.00      951.60      958.45     943.85
# 3     INFY     EQ 2017-05-18      952.80      943.00      973.90     942.85
# 4     INFY     EQ 2017-05-19      961.75      961.50      962.70     947.85
# ..     ...    ...        ...         ...         ...         ...        ...
# 491   INFY     EQ 2019-05-07      718.40      720.40      727.90     718.70
# 492   INFY     EQ 2019-05-08      724.55      721.00      726.00     716.50
# 493   INFY     EQ 2019-05-09      719.35      719.15      730.30     715.80
# 494   INFY     EQ 2019-05-10      721.05      720.80      726.00     715.00
# 495   INFY     EQ 2019-05-13      716.85      716.55      726.45     712.10
#
# ...

# %%
df1["Average Price"].mean()
# Out:
# Month  Year  Days
# 1      2018  1       1036.23
#              2       1031.43
#              3       1022.55
#              4       1014.48
#              5       1012.92
#                       ...
# 12     2018  24       652.59
#              26       641.76
#              27       658.16
#              28       658.29
#              31       659.27
# Name: Average Price, Length: 494, dtype: float64

# %%
df["Day_Perc_Change"]=df["Close Price"].pct_change()

# %%
df
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     INFY     EQ 2017-05-15      964.25      963.50      963.50     949.10
# 1     INFY     EQ 2017-05-16      951.55      953.10      960.15     946.95
# 2     INFY     EQ 2017-05-17      955.00      951.60      958.45     943.85
# 3     INFY     EQ 2017-05-18      952.80      943.00      973.90     942.85
# 4     INFY     EQ 2017-05-19      961.75      961.50      962.70     947.85
# ..     ...    ...        ...         ...         ...         ...        ...
# 491   INFY     EQ 2019-05-07      718.40      720.40      727.90     718.70
# 492   INFY     EQ 2019-05-08      724.55      721.00      726.00     716.50
# 493   INFY     EQ 2019-05-09      719.35      719.15      730.30     715.80
# 494   INFY     EQ 2019-05-10      721.05      720.80      726.00     715.00
# 495   INFY     EQ 2019-05-13      716.85      716.55      726.45     712.10
#
# ...

# %%
df.fillna(0,inplace=True)

# %%
df.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ 2017-05-15      964.25       963.5      963.50     949.10
# 1   INFY     EQ 2017-05-16      951.55       953.1      960.15     946.95
# 2   INFY     EQ 2017-05-17      955.00       951.6      958.45     943.85
# 3   INFY     EQ 2017-05-18      952.80       943.0      973.90     942.85
# 4   INFY     EQ 2017-05-19      961.75       961.5      962.70     947.85
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      953.25       951.55         951.49                3648582
# 1      956.00       955.00         952.92                3065084
# 2      952.90       952.80         949.48                1457754
# 3      960.25       961.75         962.61                4028924
# 4      957.40       957.95         954.18                2128698
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# ...

# %%
df["Trend"]=0

# %%
df.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ 2017-05-15      964.25       963.5      963.50     949.10
# 1   INFY     EQ 2017-05-16      951.55       953.1      960.15     946.95
# 2   INFY     EQ 2017-05-17      955.00       951.6      958.45     943.85
# 3   INFY     EQ 2017-05-18      952.80       943.0      973.90     942.85
# 4   INFY     EQ 2017-05-19      961.75       961.5      962.70     947.85
#
#    Last Price  Close Price  Average Price  ...      Turnover  No. of Trades  \
# 0      953.25       951.55         951.49  ...  3.471580e+09          75335
# 1      956.00       955.00         952.92  ...  2.920775e+09          71808
# 2      952.90       952.80         949.48  ...  1.384110e+09          75429
# 3      960.25       961.75         962.61  ...  3.878282e+09         120990
# 4      957.40       957.95         954.18  ...  2.031155e+09          88897
#
# ...

# %%
p1=df.loc[(df["Day_Perc_Change"]>-0.5)&(df["Day_Perc_Change"]<0.5)]

# %%
p2=df[df["Day_Perc_Change"].between(-0.5,-7)]

# %%
p1["Trend"]="Slight or No change"

# %%
p2["Trend"]="Bear drop"

# %%
p1
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     INFY     EQ 2017-05-15      964.25      963.50      963.50     949.10
# 1     INFY     EQ 2017-05-16      951.55      953.10      960.15     946.95
# 2     INFY     EQ 2017-05-17      955.00      951.60      958.45     943.85
# 3     INFY     EQ 2017-05-18      952.80      943.00      973.90     942.85
# 4     INFY     EQ 2017-05-19      961.75      961.50      962.70     947.85
# ..     ...    ...        ...         ...         ...         ...        ...
# 491   INFY     EQ 2019-05-07      718.40      720.40      727.90     718.70
# 492   INFY     EQ 2019-05-08      724.55      721.00      726.00     716.50
# 493   INFY     EQ 2019-05-09      719.35      719.15      730.30     715.80
# 494   INFY     EQ 2019-05-10      721.05      720.80      726.00     715.00
# 495   INFY     EQ 2019-05-13      716.85      716.55      726.45     712.10
#
# ...

# %%
p2
# Out:
# Empty DataFrame
# Columns: [Symbol, Series, Date, Prev Close, Open Price, High Price, Low Price, Last Price, Close Price, Average Price, Total Traded Quantity, Turnover, No. of Trades, Deliverable Qty, % Dly Qt to Traded Qty, Month, Year, Days, vwap, Day_Perc_Change, Trend]
# Index: []
#
# [0 rows x 21 columns]

# %%
p1
# Out:
#     Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0     INFY     EQ 2017-05-15      964.25      963.50      963.50     949.10
# 1     INFY     EQ 2017-05-16      951.55      953.10      960.15     946.95
# 2     INFY     EQ 2017-05-17      955.00      951.60      958.45     943.85
# 3     INFY     EQ 2017-05-18      952.80      943.00      973.90     942.85
# 4     INFY     EQ 2017-05-19      961.75      961.50      962.70     947.85
# ..     ...    ...        ...         ...         ...         ...        ...
# 491   INFY     EQ 2019-05-07      718.40      720.40      727.90     718.70
# 492   INFY     EQ 2019-05-08      724.55      721.00      726.00     716.50
# 493   INFY     EQ 2019-05-09      719.35      719.15      730.30     715.80
# 494   INFY     EQ 2019-05-10      721.05      720.80      726.00     715.00
# 495   INFY     EQ 2019-05-13      716.85      716.55      726.45     712.10
#
# ...

# %%
ANS=p1.groupby("Trend")

# %%
ANS.head()
# Out:
#   Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0   INFY     EQ 2017-05-15      964.25       963.5      963.50     949.10
# 1   INFY     EQ 2017-05-16      951.55       953.1      960.15     946.95
# 2   INFY     EQ 2017-05-17      955.00       951.6      958.45     943.85
# 3   INFY     EQ 2017-05-18      952.80       943.0      973.90     942.85
# 4   INFY     EQ 2017-05-19      961.75       961.5      962.70     947.85
#
#    Last Price  Close Price  Average Price  ...      Turnover  No. of Trades  \
# 0      953.25       951.55         951.49  ...  3.471580e+09          75335
# 1      956.00       955.00         952.92  ...  2.920775e+09          71808
# 2      952.90       952.80         949.48  ...  1.384110e+09          75429
# 3      960.25       961.75         962.61  ...  3.878282e+09         120990
# 4      957.40       957.95         954.18  ...  2.031155e+09          88897
#
# ...

# %%
ANS["Total Traded Quantity"].mean()
# Out:
# Trend
# Slight or No change    6.037975e+06
# Name: Total Traded Quantity, dtype: float64

# %%
ANS["Total Traded Quantity"].median()
# Out:
# Trend
# Slight or No change    4880990.5
# Name: Total Traded Quantity, dtype: float64
